# %% [markdown]
# <a href="https://colab.research.google.com/github/zeenau2114-design/ddp-2025/blob/main/praktikum_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
namakendaraan = "astrea"
jeniskendaraan = "motor"
cckendaraan = 160
warnakendaraan = "hitam"
rodakendaraan= 2

data_kendaraan =[
namakendaraan, jeniskendaraan, cckendaraan, warnakendaraan, rodakendaraan]

print(data_kendaraan)

hargakendaraan =5000
tipekendaraan = "gigi"

data_kendaraan.append(hargakendaraan)
data_kendaraan.append(tipekendaraan)
print(data_kendaraan)

merkkendaraan = "Honda"
data_kendaraan.insert(2, merkkendaraan)
print(data_kendaraan)
# Out:
# ['astrea', 'motor', 160, 'hitam', 2]
# ['astrea', 'motor', 160, 'hitam', 2, 5000, 'gigi']
# ['astrea', 'motor', 'Honda', 160, 'hitam', 2, 5000, 'gigi']

# %%
print("Pilih bangun datar yang ingin dihitung luasnya:")
print("1. Luas Persegi: ")
print("2. Luas Lingkaran: ")
print("3. Luas Segitiga: ")

pilihan = int(input("Masukkan pilihan (1/2/3): "))

match pilihan:
    case 1:
        sisi = float(input("Masukkan panjang sisi: "))
        luas = sisi * sisi
        print(f"Luas persegi adalah {luas}")
    case 2:
        jari_jari = float(input("Masukkan jari-jari lingkaran: "))
        luas = 3.14 * jari_jari * jari_jari
        print(f"Luas lingkaran adalah {luas}")
    case 3:
        alas = float(input("Masukkan alas segitiga: "))
        tinggi = float(input("Masukkan tinggi segitiga: "))
        luas = 0.5 * alas * tinggi
        print(f"Luas segitiga adalah {luas}")
    case _:
        print("Salah pilih! Silakan pilih 1, 2, atau 3 saja.")
# Out:
# Pilih bangun datar yang ingin dihitung luasnya:
# 1. Luas Persegi:
# 2. Luas Lingkaran:
# 3. Luas Segitiga:
# Masukkan pilihan (1/2/3): 3
# Masukkan alas segitiga: 4
# Masukkan tinggi segitiga: 5
# Luas segitiga adalah 10.0
